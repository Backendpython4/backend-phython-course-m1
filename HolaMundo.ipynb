# %%
print("Hola Mundo!")
# Out:
# Hola Mundo!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hola me llamo Gabriel de Jesús Palacios Ortiz!")
# Out:
# Hola me llamo Gabriel de Jesús Palacios Ortiz!
